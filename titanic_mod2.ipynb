# %%
# !pip install sweetviz
# !pip install plotnine
# Out:
# Requirement already satisfied: sweetviz in c:\users\hossa\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\hossa\anaconda3\lib\site-packages (from sweetviz) (2.11.2)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\hossa\anaconda3\lib\site-packages (from sweetviz) (3.4.3)
# Requirement already satisfied: importlib-resources>=1.2.0 in c:\users\hossa\anaconda3\lib\site-packages (from sweetviz) (5.2.3)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\hossa\appdata\roaming\python\python38\site-packages (from sweetviz) (4.62.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\hossa\anaconda3\lib\site-packages (from sweetviz) (1.20.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\hossa\appdata\roaming\python\python38\site-packages (from sweetviz) (1.7.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\hossa\anaconda3\lib\site-packages (from sweetviz) (1.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hossa\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (8.0.1)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in c:\users\hossa\anaconda3\lib\site-packages (from importlib-resources>=1.2.0->sweetviz) (3.4.0)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\hossa\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\hossa\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\users\hossa\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.15.0)
# Requirement already satisfied: plotnine in c:\users\hossa\anaconda3\lib\site-packages (0.8.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\hossa\anaconda3\lib\site-packages (from plotnine) (1.20.3)
# Requirement already satisfied: matplotlib>=3.1.1 in c:\users\hossa\anaconda3\lib\site-packages (from plotnine) (3.4.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\hossa\appdata\roaming\python\python38\site-packages (from plotnine) (1.7.1)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\hossa\anaconda3\lib\site-packages (from plotnine) (1.2.5)
# Requirement already satisfied: descartes>=1.1.0 in c:\users\hossa\anaconda3\lib\site-packages (from plotnine) (1.1.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\hossa\anaconda3\lib\site-packages (from plotnine) (0.13.0)
# Requirement already satisfied: mizani>=0.7.3 in c:\users\hossa\anaconda3\lib\site-packages (from plotnine) (0.7.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\hossa\anaconda3\lib\site-packages (from plotnine) (0.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib>=3.1.1->plotnine) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib>=3.1.1->plotnine) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib>=3.1.1->plotnine) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib>=3.1.1->plotnine) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib>=3.1.1->plotnine) (8.0.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\hossa\anaconda3\lib\site-packages (from pandas>=1.1.0->plotnine) (2020.1)
# Requirement already satisfied: palettable in c:\users\hossa\anaconda3\lib\site-packages (from mizani>=0.7.3->plotnine) (3.3.0)
# Requirement already satisfied: six in c:\users\hossa\anaconda3\lib\site-packages (from patsy>=0.5.1->plotnine) (1.15.0)

# %%
import pandas as pd
import numpy as np
import sweetviz as sv
import plotnine as pn

# %%
df_train = pd.read_csv('./data/train.csv')
df_test = pd.read_csv('./data/test.csv')
df_gender = pd.read_csv('./data/gender_submission.csv')

# %%
report = sv.analyze(df_train, target_feat='Survived')
report.show_html(
    filepath = 'sweetviz/report1.html'
)
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report sweetviz/report1.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Exploratory visualization for features affecting the survival rate..

# %%
# !pip install autoviz
from autoviz.AutoViz_Class import AutoViz_Class
 
AV = AutoViz_Class()
df = AV.AutoViz('./data/train.csv', depVar='Survived')
# Out:
# Requirement already satisfied: autoviz in c:\users\hossa\anaconda3\lib\site-packages (0.0.84)
# Requirement already satisfied: xgboost in c:\users\hossa\anaconda3\lib\site-packages (from autoviz) (1.5.0)
# Requirement already satisfied: pandas in c:\users\hossa\anaconda3\lib\site-packages (from autoviz) (1.2.5)
# Requirement already satisfied: scikit-learn in c:\users\hossa\appdata\roaming\python\python38\site-packages (from autoviz) (0.24.2)
# Requirement already satisfied: matplotlib in c:\users\hossa\anaconda3\lib\site-packages (from autoviz) (3.4.3)
# Requirement already satisfied: ipython in c:\users\hossa\appdata\roaming\python\python38\site-packages (from autoviz) (7.28.0)
# Requirement already satisfied: seaborn in c:\users\hossa\anaconda3\lib\site-packages (from autoviz) (0.11.0)
# Requirement already satisfied: jupyter in c:\users\hossa\anaconda3\lib\site-packages (from autoviz) (1.0.0)
# Requirement already satisfied: statsmodels in c:\users\hossa\anaconda3\lib\site-packages (from autoviz) (0.13.0)
# Requirement already satisfied: numpy in c:\users\hossa\anaconda3\lib\site-packages (from xgboost->autoviz) (1.20.3)
# Requirement already satisfied: scipy in c:\users\hossa\appdata\roaming\python\python38\site-packages (from xgboost->autoviz) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\hossa\anaconda3\lib\site-packages (from pandas->autoviz) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\hossa\anaconda3\lib\site-packages (from pandas->autoviz) (2020.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\hossa\appdata\roaming\python\python38\site-packages (from scikit-learn->autoviz) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hossa\anaconda3\lib\site-packages (from scikit-learn->autoviz) (2.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib->autoviz) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib->autoviz) (8.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib->autoviz) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hossa\anaconda3\lib\site-packages (from matplotlib->autoviz) (1.3.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\hossa\anaconda3\lib\site-packages (from ipython->autoviz) (50.3.1.post20201107)
# Requirement already satisfied: traitlets>=4.2 in c:\users\hossa\anaconda3\lib\site-packages (from ipython->autoviz) (5.0.5)
# Requirement already satisfied: backcall in c:\users\hossa\anaconda3\lib\site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: pygments in c:\users\hossa\anaconda3\lib\site-packages (from ipython->autoviz) (2.7.2)
# Requirement already satisfied: pickleshare in c:\users\hossa\anaconda3\lib\site-packages (from ipython->autoviz) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\hossa\anaconda3\lib\site-packages (from ipython->autoviz) (3.0.8)
# Requirement already satisfied: jedi>=0.16 in c:\users\hossa\anaconda3\lib\site-packages (from ipython->autoviz) (0.17.1)
# Requirement already satisfied: decorator in c:\users\hossa\anaconda3\lib\site-packages (from ipython->autoviz) (4.4.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\hossa\anaconda3\lib\site-packages (from ipython->autoviz) (0.4.4)
# Requirement already satisfied: matplotlib-inline in c:\users\hossa\appdata\roaming\python\python38\site-packages (from ipython->autoviz) (0.1.3)
# Requirement already satisfied: jupyter-console in c:\users\hossa\anaconda3\lib\site-packages (from jupyter->autoviz) (6.2.0)
# Requirement already satisfied: nbconvert in c:\users\hossa\anaconda3\lib\site-packages (from jupyter->autoviz) (6.0.7)
# Requirement already satisfied: notebook in c:\users\hossa\anaconda3\lib\site-packages (from jupyter->autoviz) (6.1.4)
# Requirement already satisfied: ipykernel in c:\users\hossa\anaconda3\lib\site-packages (from jupyter->autoviz) (5.3.4)
# Requirement already satisfied: ipywidgets in c:\users\hossa\anaconda3\lib\site-packages (from jupyter->autoviz) (7.5.1)
# Requirement already satisfied: qtconsole in c:\users\hossa\anaconda3\lib\site-packages (from jupyter->autoviz) (4.7.7)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\hossa\anaconda3\lib\site-packages (from statsmodels->autoviz) (0.5.2)
# Requirement already satisfied: six>=1.5 in c:\users\hossa\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->autoviz) (1.15.0)
# Requirement already satisfied: ipython-genutils in c:\users\hossa\anaconda3\lib\site-packages (from traitlets>=4.2->ipython->autoviz) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\hossa\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->autoviz) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\hossa\anaconda3\lib\site-packages (from jedi>=0.16->ipython->autoviz) (0.7.0)
# Requirement already satisfied: jupyter-client in c:\users\hossa\anaconda3\lib\site-packages (from jupyter-console->jupyter->autoviz) (6.1.7)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hossa\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (1.4.3)
# Requirement already satisfied: defusedxml in c:\users\hossa\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hossa\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hossa\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\hossa\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.5.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\hossa\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.3)
# Requirement already satisfied: testpath in c:\users\hossa\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.4.4)
# Requirement already satisfied: jinja2>=2.4 in c:\users\hossa\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (2.11.2)
# Requirement already satisfied: jupyter-core in c:\users\hossa\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (4.6.3)
# Requirement already satisfied: nbformat>=4.4 in c:\users\hossa\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (5.0.8)
# Requirement already satisfied: bleach in c:\users\hossa\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (3.2.1)
# Requirement already satisfied: tornado>=5.0 in c:\users\hossa\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (6.0.4)
# Requirement already satisfied: Send2Trash in c:\users\hossa\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (1.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\hossa\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (20.1.0)
# Requirement already satisfied: prometheus-client in c:\users\hossa\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (0.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hossa\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (0.9.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\hossa\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (19.0.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\hossa\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz) (3.5.1)
# Requirement already satisfied: qtpy in c:\users\hossa\anaconda3\lib\site-packages (from qtconsole->jupyter->autoviz) (1.9.0)
# Requirement already satisfied: nest-asyncio in c:\users\hossa\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->autoviz) (1.4.2)
# Requirement already satisfied: async-generator in c:\users\hossa\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->autoviz) (1.10)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hossa\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert->jupyter->autoviz) (1.1.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\hossa\anaconda3\lib\site-packages (from jupyter-core->nbconvert->jupyter->autoviz) (227)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\hossa\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert->jupyter->autoviz) (3.2.0)
# Requirement already satisfied: webencodings in c:\users\hossa\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->autoviz) (0.5.1)
# Requirement already satisfied: packaging in c:\users\hossa\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->autoviz) (20.4)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\hossa\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->autoviz) (1.14.3)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\hossa\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->autoviz) (0.5.7)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hossa\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter->autoviz) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\hossa\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert->jupyter->autoviz) (0.17.3)
# Requirement already satisfied: pycparser in c:\users\hossa\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->autoviz) (2.20)
# Imported AutoViz_Class version: 0.0.84. Call using:
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 does not show plot but creates them and saves them in AutoViz_Plots directory in your local machine.
# Shape of your Data Set loaded: (891, 12)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  3
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  1
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  2
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  2
#     Number of Columns to Delete =  0
#     11 Predictors classified...
#         This does not include the Target column(s)
#         4 variables removed since they were ID or low-information variables
#
# ################ Binary_Classification VISUALIZATION Started #####################
# Total Number of Scatter Plots = 3
# Time to run AutoViz (in seconds) = 4.696
#
#  ###################### VISUALIZATION Completed ########################

# %%
import sys
# !{sys.executable} -m pip install pycaret
# Out:
# Collecting pycaret
#   Using cached pycaret-2.3.4-py3-none-any.whl (266 kB)
# Requirement already satisfied: pandas in c:\python\python39\lib\site-packages (from pycaret) (1.2.4)
# Collecting scipy<=1.5.4
#   Using cached scipy-1.5.4-cp39-cp39-win_amd64.whl (31.4 MB)
# Requirement already satisfied: joblib in c:\python\python39\lib\site-packages (from pycaret) (1.0.1)
# Collecting pandas-profiling>=2.8.0
#   Using cached pandas_profiling-3.1.0-py2.py3-none-any.whl (261 kB)
# Collecting kmodes>=0.10.1
#   Using cached kmodes-0.11.1-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: numpy==1.19.5 in c:\python\python39\lib\site-packages (from pycaret) (1.19.5)
# Collecting cufflinks>=0.17.0
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# Collecting wordcloud
#   Using cached wordcloud-1.8.1.tar.gz (220 kB)
# Collecting scikit-plot
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting Boruta
#   Using cached Boruta-0.3-py3-none-any.whl (56 kB)
# Collecting yellowbrick>=1.0.1
#   Using cached yellowbrick-1.3.post1-py3-none-any.whl (271 kB)
# Collecting umap-learn
#   Using cached umap_learn-0.5.1-py3-none-any.whl
# Collecting spacy<2.4.0
#   Using cached spacy-2.3.7-cp39-cp39-win_amd64.whl (9.4 MB)
# Collecting seaborn
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Collecting pyod
#   Using cached pyod-0.9.4-py3-none-any.whl
# Collecting mlxtend>=0.17.0
#   Using cached mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
# Collecting scikit-learn==0.23.2
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Collecting pycaret
#   Using cached pycaret-2.3.3-py3-none-any.whl (264 kB)
#   Using cached pycaret-2.3.2-py3-none-any.whl (263 kB)
#   Using cached pycaret-2.3.1-py3-none-any.whl (261 kB)
#   Using cached pycaret-2.3.0-py3-none-any.whl (261 kB)
# Collecting imbalanced-learn>=0.7.0
#   Using cached imbalanced_learn-0.8.1-py3-none-any.whl (189 kB)
# Collecting pycaret
#   Using cached pycaret-2.2.3-py3-none-any.whl (249 kB)
# Collecting spacy
#   Using cached spacy-3.1.3-cp39-cp39-win_amd64.whl (11.6 MB)
# Collecting pycaret
#   Using cached pycaret-2.2.2-py3-none-any.whl (249 kB)
# Collecting gensim
#   Using cached gensim-4.1.2-cp39-cp39-win_amd64.whl (24.0 MB)
# Collecting catboost>=0.23.2
# Error processing line 7 of C:\python\python39\lib\site-packages\pywin32.pth:
#
#   Traceback (most recent call last):
#     File "C:\python\python39\lib\site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
# Remainder of file ignored
# WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\python\python39\python.exe' 'C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-standalone-pip-42j7nezk\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-build-env-cpcepcre\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1'
#        cwd: None
#   Complete output (636 lines):
#   Error processing line 7 of C:\python\python39\lib\site-packages\pywin32.pth:
#
#     Traceback (most recent call last):
#       File "C:\python\python39\lib\site.py", line 169, in addpackage
#         exec(line)
#       File "<string>", line 1, in <module>
#     ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
#   Remainder of file ignored
#   WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-58.2.0-py3-none-any.whl (946 kB)
#   Collecting wheel
#     Using cached wheel-0.37.0-py2.py3-none-any.whl (35 kB)
#   Collecting Cython>=0.28.5
#     Using cached Cython-0.29.24-cp39-cp39-win_amd64.whl (1.7 MB)
#   Collecting numpy==1.17.3
#     Using cached numpy-1.17.3.zip (6.4 MB)
#   Collecting scipy>=0.19.1
#     Using cached scipy-1.7.1-cp39-cp39-win_amd64.whl (33.8 MB)
#   Building wheels for collected packages: numpy
#     Building wheel for numpy (setup.py): started
#     Building wheel for numpy (setup.py): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\python\python39\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Mohammad Saudi\\AppData\\Local\\Temp\\pip-install-immbowvc\\numpy_265bd8f584c64a04996d0b7915e7cbc6\\setup.py'"'"'; __file__='"'"'C:\\Users\\Mohammad Saudi\\AppData\\Local\\Temp\\pip-install-immbowvc\\numpy_265bd8f584c64a04996d0b7915e7cbc6\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-wheel-qirlgv_y'
#          cwd: C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-immbowvc\numpy_265bd8f584c64a04996d0b7915e7cbc6\
#     Complete output (277 lines):
#     Error processing line 7 of C:\python\python39\lib\site-packages\pywin32.pth:
#
#       Traceback (most recent call last):
#   Using cached catboost-1.0.0-cp39-none-win_amd64.whl (77.3 MB)
# Requirement already satisfied: IPython in c:\python\python39\lib\site-packages (from pycaret) (7.24.1)
# Collecting lightgbm>=2.3.1
#   Using cached lightgbm-3.3.0-py3-none-win_amd64.whl (1.0 MB)
# Collecting ipywidgets
#   Using cached ipywidgets-7.6.5-py2.py3-none-any.whl (121 kB)
# Collecting plotly>=4.4.1
#   Using cached plotly-5.3.1-py2.py3-none-any.whl (23.9 MB)
# Collecting mlflow
#   Using cached mlflow-1.20.2-py3-none-any.whl (14.6 MB)
# Collecting pyLDAvis
#   Using cached pyLDAvis-3.3.1.tar.gz (1.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting xgboost>=1.1.0
#   Using cached xgboost-1.5.0-py3-none-win_amd64.whl (106.6 MB)
# Requirement already satisfied: matplotlib in c:\python\python39\lib\site-packages (from pycaret) (3.4.2)
# Collecting nltk
#   Using cached nltk-3.6.5-py3-none-any.whl (1.5 MB)
# Collecting textblob
#   Using cached textblob-0.15.3-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: scikit-learn>=0.23.2 in c:\python\python39\lib\site-packages (from pycaret) (0.24.2)
# Requirement already satisfied: six in c:\python\python39\lib\site-packages (from catboost>=0.23.2->pycaret) (1.15.0)
# Requirement already satisfied: scipy in c:\python\python39\lib\site-packages (from catboost>=0.23.2->pycaret) (1.6.2)
# Requirement already satisfied: graphviz in c:\python\python39\lib\site-packages (from catboost>=0.23.2->pycaret) (0.16)
# Collecting colorlover>=0.2.1
#   Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in c:\python\python39\lib\site-packages (from cufflinks>=0.17.0->pycaret) (49.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\python\python39\lib\site-packages (from IPython->pycaret) (0.18.0)
# Requirement already satisfied: backcall in c:\python\python39\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: colorama in c:\python\python39\lib\site-packages (from IPython->pycaret) (0.4.4)
# Requirement already satisfied: pickleshare in c:\python\python39\lib\site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\python\python39\lib\site-packages (from IPython->pycaret) (3.0.19)
# Requirement already satisfied: pygments in c:\python\python39\lib\site-packages (from IPython->pycaret) (2.9.0)
# Requirement already satisfied: decorator in c:\python\python39\lib\site-packages (from IPython->pycaret) (5.0.9)
# Requirement already satisfied: traitlets>=4.2 in c:\python\python39\lib\site-packages (from IPython->pycaret) (5.0.5)
# Requirement already satisfied: matplotlib-inline in c:\python\python39\lib\site-packages (from IPython->pycaret) (0.1.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\python\python39\lib\site-packages (from ipywidgets->pycaret) (0.2.0)
# Collecting widgetsnbextension~=3.5.0
#   Using cached widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
# Collecting jupyterlab-widgets>=1.0.0
#   Using cached jupyterlab_widgets-1.0.2-py3-none-any.whl (243 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\python\python39\lib\site-packages (from ipywidgets->pycaret) (5.5.5)
# Requirement already satisfied: nbformat>=4.2.0 in c:\python\python39\lib\site-packages (from ipywidgets->pycaret) (5.1.3)
# Requirement already satisfied: jupyter-client in c:\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\python\python39\lib\site-packages (from jedi>=0.16->IPython->pycaret) (0.8.2)
# Requirement already satisfied: wheel in c:\python\python39\lib\site-packages (from lightgbm>=2.3.1->pycaret) (0.37.0)
# Requirement already satisfied: jupyter-core in c:\python\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\python\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\python\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pycaret) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\python\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->pycaret) (21.2.0)
# Requirement already satisfied: pytz>=2017.3 in c:\python\python39\lib\site-packages (from pandas->pycaret) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\python\python39\lib\site-packages (from pandas->pycaret) (2.8.1)
# Collecting multimethod>=1.4
#   Using cached multimethod-1.6-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: pydantic>=1.8.1 in c:\python\python39\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (1.8.2)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\python\python39\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (5.4.1)
# Collecting htmlmin>=0.1.12
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# Collecting tangled-up-in-unicode==0.1.0
#   Using cached tangled_up_in_unicode-0.1.0-py3-none-any.whl (3.1 MB)
# Requirement already satisfied: requests>=2.24.0 in c:\python\python39\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (2.26.0)
# Requirement already satisfied: markupsafe~=2.0.1 in c:\python\python39\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (2.0.1)
# Collecting phik>=0.11.1
#   Using cached phik-0.12.0-cp39-cp39-win_amd64.whl (659 kB)
# Requirement already satisfied: tqdm>=4.48.2 in c:\python\python39\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (4.62.2)
# Requirement already satisfied: jinja2>=2.11.1 in c:\python\python39\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (3.0.1)
# Collecting missingno>=0.4.2
#   Using cached missingno-0.5.0-py3-none-any.whl (8.8 kB)
# Collecting visions[type_image_path]==0.7.4
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Requirement already satisfied: networkx>=2.4 in c:\python\python39\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (2.6.3)
# Requirement already satisfied: Pillow in c:\python\python39\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (8.2.0)
# Collecting imagehash
#   Using cached ImageHash-4.2.1-py2.py3-none-any.whl
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python\python39\lib\site-packages (from matplotlib->pycaret) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\python\python39\lib\site-packages (from matplotlib->pycaret) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python\python39\lib\site-packages (from matplotlib->pycaret) (1.3.1)
# Collecting tenacity>=6.2.0
#   Using cached tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: wcwidth in c:\python\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\python\python39\lib\site-packages (from pydantic>=1.8.1->pandas-profiling>=2.8.0->pycaret) (3.7.4.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\python\python39\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\python39\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\python39\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python\python39\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (1.26.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python\python39\lib\site-packages (from scikit-learn>=0.23.2->pycaret) (2.1.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\python\python39\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.0)
# Requirement already satisfied: pyzmq>=17 in c:\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (22.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.10.1)
# Requirement already satisfied: prometheus-client in c:\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.11.0)
# Requirement already satisfied: argon2-cffi in c:\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (20.1.0)
# Requirement already satisfied: nbconvert in c:\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.0.7)
# Collecting pywin32>=1.0
#   Using cached pywin32-302-cp39-cp39-win_amd64.whl (9.3 MB)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\python\python39\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.1.2)
# Requirement already satisfied: cffi>=1.0.0 in c:\python\python39\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.14.5)
# Requirement already satisfied: pycparser in c:\python\python39\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.20)
# Collecting smart-open>=1.8.1
#   Using cached smart_open-5.2.1-py3-none-any.whl (58 kB)
# Collecting Cython==0.29.23
#   Using cached Cython-0.29.23-cp39-cp39-win_amd64.whl (1.7 MB)
# Requirement already satisfied: PyWavelets in c:\python\python39\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (1.1.1)
#         File "C:\python\python39\lib\site.py", line 169, in addpackage
#           exec(line)
#         File "<string>", line 1, in <module>
#       ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
#     Remainder of file ignored
#     Running from numpy source directory.
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blis not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-immbowvc\numpy_265bd8f584c64a04996d0b7915e7cbc6\numpy\distutils\system_info.py:690: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       self.calc_info()
#     blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-immbowvc\numpy_265bd8f584c64a04996d0b7915e7cbc6\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-immbowvc\numpy_265bd8f584c64a04996d0b7915e7cbc6\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion' is not recognized as an internal or external command,
#     operable program or batch file.
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas,lapack not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     flame_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries flame not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\python\python39\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\python\python39\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\python\python39\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\python\python39\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
# Requirement already satisfied: Flask in c:\python\python39\lib\site-packages (from mlflow->pycaret) (2.0.1)
# Collecting querystring-parser
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting gitpython>=2.1.0
#   Using cached GitPython-3.1.24-py3-none-any.whl (180 kB)
# Requirement already satisfied: entrypoints in c:\python\python39\lib\site-packages (from mlflow->pycaret) (0.3)
# Collecting sqlparse>=0.3.1
#   Using cached sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Collecting sqlalchemy
#   Using cached SQLAlchemy-1.4.25-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting alembic<=1.4.1
#   Using cached alembic-1.4.1-py2.py3-none-any.whl
# Collecting waitress
#   Using cached waitress-2.0.0-py3-none-any.whl (56 kB)
# Collecting importlib-metadata!=4.7.0,>=3.7.0
#   Using cached importlib_metadata-4.8.1-py3-none-any.whl (17 kB)
# Collecting prometheus-flask-exporter
#   Using cached prometheus_flask_exporter-0.18.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: click>=7.0 in c:\python\python39\lib\site-packages (from mlflow->pycaret) (8.0.1)
# Collecting databricks-cli>=0.8.7
#   Using cached databricks_cli-0.16.0-py3-none-any.whl
# Collecting docker>=4.0.0
#   Using cached docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied: protobuf>=3.7.0 in c:\python\python39\lib\site-packages (from mlflow->pycaret) (3.17.3)
# Requirement already satisfied: cloudpickle in c:\python\python39\lib\site-packages (from mlflow->pycaret) (1.3.0)
# Requirement already satisfied: packaging in c:\python\python39\lib\site-packages (from mlflow->pycaret) (20.9)
# Collecting Mako
#   Using cached Mako-1.1.5-py2.py3-none-any.whl (75 kB)
# Collecting python-editor>=0.3
#   Using cached python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Requirement already satisfied: tabulate>=0.7.7 in c:\python\python39\lib\site-packages (from databricks-cli>=0.8.7->mlflow->pycaret) (0.8.9)
# Collecting pywin32>=1.0
#   Using cached pywin32-227-cp39-cp39-win_amd64.whl (9.1 MB)
# Collecting websocket-client>=0.32.0
#   Using cached websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.7-py3-none-any.whl (63 kB)
# Collecting smmap<5,>=3.0.1
#   Using cached smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in c:\python\python39\lib\site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->pycaret) (3.6.0)
# Collecting greenlet!=0.4.17
#   Using cached greenlet-1.1.2-cp39-cp39-win_amd64.whl (101 kB)
# Requirement already satisfied: Werkzeug>=2.0 in c:\python\python39\lib\site-packages (from Flask->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: itsdangerous>=2.0 in c:\python\python39\lib\site-packages (from Flask->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: jupyterlab-pygments in c:\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.1.2)
# Requirement already satisfied: testpath in c:\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.0)
# Requirement already satisfied: defusedxml in c:\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.3)
# Requirement already satisfied: bleach in c:\python\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (3.3.0)
# Requirement already satisfied: nest-asyncio in c:\python\python39\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.5.1)
# Requirement already satisfied: async-generator in c:\python\python39\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.10)
# Requirement already satisfied: webencodings in c:\python\python39\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.1)
# Collecting regex>=2021.8.3
#   Using cached regex-2021.10.8-cp39-cp39-win_amd64.whl (273 kB)
# Collecting numexpr
#   Using cached numexpr-2.7.3-cp39-cp39-win_amd64.whl (93 kB)
# Requirement already satisfied: future in c:\python\python39\lib\site-packages (from pyLDAvis->pycaret) (0.18.2)
# Collecting pyLDAvis
#   Using cached pyLDAvis-3.3.0.tar.gz (1.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
#   Using cached pyLDAvis-3.2.2-py2.py3-none-any.whl
# Collecting funcy
#   Using cached funcy-1.16-py2.py3-none-any.whl (32 kB)
# Collecting numba>=0.35
#   Using cached numba-0.54.1-cp39-cp39-win_amd64.whl (2.3 MB)
# Requirement already satisfied: statsmodels in c:\python\python39\lib\site-packages (from pyod->pycaret) (0.12.2)
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Using cached llvmlite-0.37.0-cp39-cp39-win_amd64.whl (17.0 MB)
# Collecting srsly<3.0.0,>=2.4.1
#   Using cached srsly-2.4.1-cp39-cp39-win_amd64.whl (451 kB)
# Collecting typer<0.5.0,>=0.3.0
#   Using cached typer-0.4.0-py3-none-any.whl (27 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.5-cp39-cp39-win_amd64.whl (36 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.6-py3-none-any.whl (17 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.5-cp39-cp39-win_amd64.whl (21 kB)
# Collecting thinc<8.1.0,>=8.0.9
#   Using cached thinc-8.0.10-cp39-cp39-win_amd64.whl (1.0 MB)
# Collecting blis<0.8.0,>=0.4.0
#   Using cached blis-0.7.4-cp39-cp39-win_amd64.whl (6.5 MB)
# Collecting wasabi<1.1.0,>=0.8.1
#   Using cached wasabi-0.8.2-py3-none-any.whl (23 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Using cached spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.5-cp39-cp39-win_amd64.whl (112 kB)
# Collecting pathy>=0.3.5
#   Using cached pathy-0.6.0-py3-none-any.whl (42 kB)
# Requirement already satisfied: patsy>=0.5 in c:\python\python39\lib\site-packages (from statsmodels->pyod->pycaret) (0.5.1)
# Collecting pynndescent>=0.5
#   Using cached pynndescent-0.5.5-py3-none-any.whl
# Building wheels for collected packages: wordcloud
#   Building wheel for wordcloud (setup.py): started
#   Building wheel for wordcloud (setup.py): finished with status 'error'
#   Running setup.py clean for wordcloud
# Failed to build wordcloud
# Installing collected packages: pywin32, tangled-up-in-unicode, smmap, murmurhash, multimethod, llvmlite, greenlet, cymem, catalogue, widgetsnbextension, websocket-client, wasabi, visions, typer, tenacity, srsly, sqlalchemy, smart-open, seaborn, regex, python-editor, preshed, numba, Mako, jupyterlab-widgets, imagehash, gitdb, blis, waitress, thinc, sqlparse, spacy-legacy, querystring-parser, pynndescent, prometheus-flask-exporter, plotly, phik, pathy, numexpr, nltk, missingno, ipywidgets, importlib-metadata, htmlmin, gitpython, funcy, docker, databricks-cli, Cython, colorlover, alembic, yellowbrick, xgboost, wordcloud, umap-learn, textblob, spacy, scikit-plot, pyod, pyLDAvis, pandas-profiling, mlxtend, mlflow, lightgbm, kmodes, imbalanced-learn, gensim, cufflinks, catboost, pycaret
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\python\python39\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\python\python39\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\python\python39\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\python\python39\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\python\python39\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\python\python39\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\python\python39\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\python\python39\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\python\python39\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\python\python39\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\python\python39\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\python\python39\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#       NOT AVAILABLE
#
#     C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-immbowvc\numpy_265bd8f584c64a04996d0b7915e7cbc6\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-immbowvc\numpy_265bd8f584c64a04996d0b7915e7cbc6\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#       NOT AVAILABLE
#
#     C:\python\python39\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running bdist_wheel
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build\src.win-amd64-3.9
#     creating build\src.win-amd64-3.9\numpy
#     creating build\src.win-amd64-3.9\numpy\distutils
#     building library "npymath" sources
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     error: Microsoft Visual C++ 14.0 is required. Get it with "Build Tools for Visual Studio": https://visualstudio.microsoft.com/downloads/
#     ----------------------------------------
#     ERROR: Failed building wheel for numpy
#     Running setup.py clean for numpy
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\python\python39\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Mohammad Saudi\\AppData\\Local\\Temp\\pip-install-immbowvc\\numpy_265bd8f584c64a04996d0b7915e7cbc6\\setup.py'"'"'; __file__='"'"'C:\\Users\\Mohammad Saudi\\AppData\\Local\\Temp\\pip-install-immbowvc\\numpy_265bd8f584c64a04996d0b7915e7cbc6\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#          cwd: C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-immbowvc\numpy_265bd8f584c64a04996d0b7915e7cbc6
#     Complete output (19 lines):
#     Error processing line 7 of C:\python\python39\lib\site-packages\pywin32.pth:
#
#       Traceback (most recent call last):
#         File "C:\python\python39\lib\site.py", line 169, in addpackage
#           exec(line)
#         File "<string>", line 1, in <module>
#       ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
#     Remainder of file ignored
#     Running from numpy source directory.
#
#     `setup.py clean` is not supported, use one of the following instead:
#
#       - `git clean -xdf` (cleans all files)
#       - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                           files that aren't checked into the git repo)
#
#     Add `--force` to your command to use it anyway if you must (unsupported).
#
#     ----------------------------------------
#     ERROR: Failed cleaning build dir for numpy
#   Failed to build numpy
#   WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
#   Installing collected packages: numpy, wheel, setuptools, scipy, Cython
#       Running setup.py install for numpy: started
#       Running setup.py install for numpy: finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'C:\python\python39\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Mohammad Saudi\\AppData\\Local\\Temp\\pip-install-immbowvc\\numpy_265bd8f584c64a04996d0b7915e7cbc6\\setup.py'"'"'; __file__='"'"'C:\\Users\\Mohammad Saudi\\AppData\\Local\\Temp\\pip-install-immbowvc\\numpy_265bd8f584c64a04996d0b7915e7cbc6\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-record-1i0e8t69\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-build-env-cpcepcre\overlay' --compile --install-headers 'C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-build-env-cpcepcre\overlay\Include\numpy'
#            cwd: C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-immbowvc\numpy_265bd8f584c64a04996d0b7915e7cbc6\
#       Complete output (282 lines):
#       Error processing line 7 of C:\python\python39\lib\site-packages\pywin32.pth:
#
#         Traceback (most recent call last):
#           File "C:\python\python39\lib\site.py", line 169, in addpackage
#             exec(line)
#           File "<string>", line 1, in <module>
#         ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
#       Remainder of file ignored
#       Running from numpy source directory.
#
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       blas_opt_info:
#       blas_mkl_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries mkl_rt not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#         NOT AVAILABLE
#
#       blis_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries blis not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#         NOT AVAILABLE
#
#       openblas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#       get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#       customize GnuFCompiler
#       Could not locate executable g77
#       Could not locate executable f77
#       customize IntelVisualFCompiler
#       Could not locate executable ifort
#       Could not locate executable ifl
#       customize AbsoftFCompiler
#       Could not locate executable f90
#       customize CompaqVisualFCompiler
#       Could not locate executable DF
#       customize IntelItaniumVisualFCompiler
#       Could not locate executable efl
#       customize Gnu95FCompiler
#       Could not locate executable gfortran
#       Could not locate executable f95
#       customize G95FCompiler
#       Could not locate executable g95
#       customize IntelEM64VisualFCompiler
#       customize IntelEM64TFCompiler
#       Could not locate executable efort
#       Could not locate executable efc
#       customize PGroupFlangCompiler
#       Could not locate executable flang
#       don't know how to compile Fortran code on platform 'nt'
#         NOT AVAILABLE
#
#       atlas_3_10_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#         NOT AVAILABLE
#
#       accelerate_info:
#         NOT AVAILABLE
#
#       C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-immbowvc\numpy_265bd8f584c64a04996d0b7915e7cbc6\numpy\distutils\system_info.py:690: UserWarning:
#           Optimized (vendor) Blas libraries are not found.
#           Falls back to netlib Blas library which has worse performance.
#           A better performance should be easily gained by switching
#           Blas library.
#         self.calc_info()
#       blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries blas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#         NOT AVAILABLE
#
#       C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-immbowvc\numpy_265bd8f584c64a04996d0b7915e7cbc6\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       blas_src_info:
#         NOT AVAILABLE
#
#       C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-immbowvc\numpy_265bd8f584c64a04996d0b7915e7cbc6\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#         NOT AVAILABLE
#
#       'svnversion' is not recognized as an internal or external command,
#       operable program or batch file.
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       lapack_opt_info:
#       lapack_mkl_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries mkl_rt not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#         NOT AVAILABLE
#
#       openblas_lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#         NOT AVAILABLE
#
#       openblas_clapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas,lapack not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#         NOT AVAILABLE
#
#       flame_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries flame not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\python\python39\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\python\python39\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\python\python39\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\python\python39\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#         NOT AVAILABLE
#
#       atlas_3_10_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\python\python39\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\python\python39\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\python\python39\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\python\python39\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_info'>
#         NOT AVAILABLE
#
#       atlas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\python\python39\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\python\python39\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\python\python39\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\python\python39\libs
#       <class 'numpy.distutils.system_info.atlas_threads_info'>
#         NOT AVAILABLE
#
#       atlas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\python\python39\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\python\python39\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\python\python39\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\python\python39\libs
#       <class 'numpy.distutils.system_info.atlas_info'>
#         NOT AVAILABLE
#
#       lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack not found in ['C:\\python\\python39\\lib', 'C:\\', 'C:\\python\\python39\\libs']
#         NOT AVAILABLE
#
#       C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-immbowvc\numpy_265bd8f584c64a04996d0b7915e7cbc6\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#       lapack_src_info:
#         NOT AVAILABLE
#
#       C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-immbowvc\numpy_265bd8f584c64a04996d0b7915e7cbc6\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#         NOT AVAILABLE
#
#       C:\python\python39\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running install
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       building library "npymath" sources
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       error: Microsoft Visual C++ 14.0 is required. Get it with "Build Tools for Visual Studio": https://visualstudio.microsoft.com/downloads/
#       ----------------------------------------
#   ERROR: Command errored out with exit status 1: 'C:\python\python39\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Mohammad Saudi\\AppData\\Local\\Temp\\pip-install-immbowvc\\numpy_265bd8f584c64a04996d0b7915e7cbc6\\setup.py'"'"'; __file__='"'"'C:\\Users\\Mohammad Saudi\\AppData\\Local\\Temp\\pip-install-immbowvc\\numpy_265bd8f584c64a04996d0b7915e7cbc6\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-record-1i0e8t69\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-build-env-cpcepcre\overlay' --compile --install-headers 'C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-build-env-cpcepcre\overlay\Include\numpy' Check the logs for full command output.
#   WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
#   WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
#   WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
#   WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
#   You should consider upgrading via the 'C:\python\python39\python.exe -m pip install --upgrade pip' command.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/aa/f6/75297be19f48b7a8c2577753a3a700f98fc4db49d0e5ed3820dd8dee43d4/scikit-learn-0.23.2.tar.gz#sha256=20766f515e6cd6f954554387dfae705d93c7b544ec0e6c6a5d8e006f6f7ef480 (from https://pypi.org/simple/scikit-learn/) (requires-python:>=3.6). Command errored out with exit status 1: 'C:\python\python39\python.exe' 'C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-standalone-pip-42j7nezk\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-build-env-cpcepcre\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1' Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\python\python39\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Mohammad Saudi\\AppData\\Local\\Temp\\pip-install-_jkhevhg\\wordcloud_9f5176e7d8e64ee2bdbb2e59d1288277\\setup.py'"'"'; __file__='"'"'C:\\Users\\Mohammad Saudi\\AppData\\Local\\Temp\\pip-install-_jkhevhg\\wordcloud_9f5176e7d8e64ee2bdbb2e59d1288277\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-wheel-cshp2jla'
#        cwd: C:\Users\Mohammad Saudi\AppData\Local\Temp\pip-install-_jkhevhg\wordcloud_9f5176e7d8e64ee2bdbb2e59d1288277\
#   Complete output (29 lines):
#   Error processing line 7 of C:\python\python39\lib\site-packages\pywin32.pth:
#
#     Traceback (most recent call last):
#       File "C:\python\python39\lib\site.py", line 169, in addpackage
#         exec(line)
#       File "<string>", line 1, in <module>
#     ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
#   Remainder of file ignored
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\color_from_image.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\tokenization.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\wordcloud_cli.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\_version.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\__init__.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\__main__.py -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\stopwords -> build\lib.win-amd64-3.9\wordcloud
#   copying wordcloud\DroidSansMono.ttf -> build\lib.win-amd64-3.9\wordcloud
#   UPDATING build\lib.win-amd64-3.9\wordcloud/_version.py
#   set build\lib.win-amd64-3.9\wordcloud/_version.py to '1.8.1'
#   running build_ext
#   building 'wordcloud.query_integral_image' extension
#   error: Microsoft Visual C++ 14.0 is required. Get it with "Build Tools for Visual Studio": https://visualstudio.microsoft.com/downloads/
#   ----------------------------------------
#   ERROR: Failed building wheel for wordcloud
# WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\python\\python39\\Lib\\site-packages\\win32\\_win32sysloader.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the 'C:\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
df_train.drop(columns=['Pclass', 'PassengerId', 'Name', 'Ticket', 'Cabin', 'Embarked'], inplace=True )
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Sex       891 non-null    object
#  2   Age       714 non-null    float64
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Fare      891 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 41.9+ KB

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.3.0-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\python\python39\lib\site-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: pandas>=0.21.1 in c:\python\python39\lib\site-packages (from category_encoders) (1.2.4)
# Requirement already satisfied: scipy>=1.0.0 in c:\python\python39\lib\site-packages (from category_encoders) (1.6.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\python\python39\lib\site-packages (from category_encoders) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\python\python39\lib\site-packages (from category_encoders) (0.24.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\python\python39\lib\site-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: pytz>=2017.3 in c:\python\python39\lib\site-packages (from pandas>=0.21.1->category_encoders) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\python\python39\lib\site-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: six in c:\python\python39\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in c:\python\python39\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python\python39\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.1.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.3.0
# Error processing line 7 of c:\python\python39\lib\site-packages\pywin32.pth:
#
#   Traceback (most recent call last):
#     File "c:\python\python39\lib\site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
# Remainder of file ignored
# WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ywin32 (c:\python\python39\lib\site-packages)
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the 'c:\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()  #instantiate the Label Encoder
df_train['Sex'] = le.fit_transform(df_train['Sex'])
df_train.Age.fillna(df_train.Age.mean(), inplace=True)

# %%
from sklearn.model_selection import train_test_split
X = df_train.drop(columns='Survived')
y = df_train[['Survived']]

# %%
X_train, X_test, y_train, y_test = train_test_split(
                         X, y, test_size=0.20, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((712, 5), (179, 5), (712, 1), (179, 1))

# %%
# from sklearn.linear_model import LinearRegression

# reg = LinearRegression().fit(X_train.values, y_train.values)
# reg.score(X, y)
# reg.coef_
# reg.intercept_
# predict = reg.predict(X_test)

# %%
from sklearn.linear_model import LinearRegression
linear_regression_model = LinearRegression()
linear_regression_model.fit(X_train, y_train)
linear_regression_predictions = linear_regression_model.predict(X_train)

# %%
# defining evaluation metric
def compute_rmse(actual, prediction):
    """
    Computs RMSE (root mean squared error) between predictions from a model
    and the actual values of the target variable.
    """
    
    rmse = sqrt(mean_squared_error(actual, prediction))
    
    # rounding to 2 decimal places
    print('RMSE is ', round(rmse,2))
    
    return rmse

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
linear_regression_rmse = compute_rmse(y_train, linear_regression_predictions)
# Out:
# RMSE is  0.39

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_model = RandomForestRegressor()
random_forest_model.fit(X_train, y_train)
random_forest_predictions = random_forest_model.predict(X_train)
random_forest_rmse = compute_rmse(y_train, random_forest_predictions)
# Out:
# <ipython-input-97-fa2966ac75aa>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RMSE is  0.17

# %%
df_train.head()
# Out:
#    Survived  Sex   Age  SibSp  Parch     Fare
# 0         0    1  22.0      1      0   7.2500
# 1         1    0  38.0      1      0  71.2833
# 2         1    0  26.0      0      0   7.9250
# 3         1    0  35.0      1      0  53.1000
# 4         0    1  35.0      0      0   8.0500

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics 
logmodel = LogisticRegression(solver='liblinear')
logmodel.fit(X_train,y_train)

predictions = logmodel.predict(X_test)

print(metrics.classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82       105
#            1       0.76      0.69      0.72        74
#
#     accuracy                           0.78       179
#    macro avg       0.78      0.77      0.77       179
# weighted avg       0.78      0.78      0.78       179
# C:\python\python39\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
